# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # 1. Data importing

# %%
oil_data = pd.read_csv('oil_spill.csv')
oil_data
# Out:
#      f_1    f_2      f_3     f_4  f_5       f_6    f_7    f_8      f_9  f_10  \
# 0      1   2558  1506.09  456.63   90   6395000  40.88   7.89  29780.0  0.19
# 1      2  22325    79.11  841.03  180  55812500  51.11   1.21  61900.0  0.02
# 2      3    115  1449.85  608.43   88    287500  40.42   7.34   3340.0  0.18
# 3      4   1201  1562.53  295.65   66   3002500  42.40   7.97  18030.0  0.19
# 4      5    312   950.27  440.86   37    780000  41.43   7.03   3350.0  0.17
# ..   ...    ...      ...     ...  ...       ...    ...    ...      ...   ...
# 932  200     12    92.42  364.42  135     97200  59.42  10.34    884.0  0.17
# 933  201     11    98.82  248.64  159     89100  59.64  10.18    831.0  0.17
# 934  202     14    25.14  428.86   24    113400  60.14  17.94    847.0  0.30
# 935  203     10    96.00  451.30   68     81000  59.90  15.01    831.0  0.25
# 936  204     11     7.73  235.73  135     89100  61.82  12.24    831.0  0.20
#
#      ...     f_41      f_42     f_43     f_44   f_45  f_46      f_47   f_48  \
# 0    ...  2850.00   1000.00   763.16   135.46   3.73     0  33243.19  65.74
# 1    ...  5750.00  11500.00  9593.48  1648.80   0.60     0  51572.04  65.73
# 2    ...  1400.00    250.00   150.00    45.13   9.33     1  31692.84  65.81
# 3    ...  6041.52    761.58   453.21   144.97  13.33     1  37696.21  65.67
# 4    ...  1320.04    710.63   512.54   109.16   2.58     0  29038.17  65.66
# ..   ...      ...       ...      ...      ...    ...   ...       ...    ...
# 932  ...   381.84    254.56    84.85   146.97   4.50     0   2593.50  65.85
# 933  ...   284.60    180.00   150.00    51.96   1.90     0   4361.25  65.70
# 934  ...   402.49    180.00   180.00     0.00   2.24     0   2153.05  65.91
# 935  ...   402.49    180.00    90.00    73.48   4.47     0   2421.43  65.97
# 936  ...   254.56    254.56   127.28   180.00   2.00     0   3782.68  65.65
#
#      f_49  target
# 0    7.95       1
# 1    6.26       0
# 2    7.84       1
# 3    8.07       1
# 4    7.35       0
# ..    ...     ...
# 932  6.39       0
# 933  6.53       0
# 934  6.12       0
# 935  6.32       0
# 936  6.26       0
#
# [937 rows x 50 columns]

# %%
oil_data.iloc[:,22:]
# Out:
#      f_23  f_24    f_25  f_26  f_27  f_28  f_29  f_30  f_31  f_32  ...  \
# 0       0  0.47  132.78 -0.01  3.78  0.22  3.20 -3.71 -0.18  2.19  ...
# 1       0  0.58  132.78 -0.01  3.78  0.84  7.09 -2.21  0.00  0.00  ...
# 2       0  0.46  132.78 -0.01  3.78  0.70  4.79 -3.36 -0.23  1.95  ...
# 3       0  0.48  132.78 -0.01  3.78  0.84  6.78 -3.54 -0.33  2.20  ...
# 4       0  0.47  132.78 -0.01  3.78  0.02  2.28 -3.44 -0.44  2.19  ...
# ..    ...   ...     ...   ...   ...   ...   ...   ...   ...   ...  ...
# 932     0  1.06  221.97  0.87  5.07  0.95  3.03 -1.25 -0.53  1.10  ...
# 933     0  1.07  221.97  0.87  5.07  1.19  3.39 -1.70 -0.64  1.23  ...
# 934     0  1.08  221.97  0.87  5.07  1.60  5.08 -0.90 -0.55  1.09  ...
# 935     0  1.07  221.97  0.87  5.07  0.99  2.94 -1.31 -0.36  1.09  ...
# 936     0  1.11  221.97  0.87  5.07  1.20  3.03 -0.73 -0.50  1.23  ...
#
#         f_41      f_42     f_43     f_44   f_45  f_46      f_47   f_48  f_49  \
# 0    2850.00   1000.00   763.16   135.46   3.73     0  33243.19  65.74  7.95
# 1    5750.00  11500.00  9593.48  1648.80   0.60     0  51572.04  65.73  6.26
# 2    1400.00    250.00   150.00    45.13   9.33     1  31692.84  65.81  7.84
# 3    6041.52    761.58   453.21   144.97  13.33     1  37696.21  65.67  8.07
# 4    1320.04    710.63   512.54   109.16   2.58     0  29038.17  65.66  7.35
# ..       ...       ...      ...      ...    ...   ...       ...    ...   ...
# 932   381.84    254.56    84.85   146.97   4.50     0   2593.50  65.85  6.39
# 933   284.60    180.00   150.00    51.96   1.90     0   4361.25  65.70  6.53
# 934   402.49    180.00   180.00     0.00   2.24     0   2153.05  65.91  6.12
# 935   402.49    180.00    90.00    73.48   4.47     0   2421.43  65.97  6.32
# 936   254.56    254.56   127.28   180.00   2.00     0   3782.68  65.65  6.26
#
#      target
# 0         1
# 1         0
# 2         1
# 3         1
# 4         0
# ..      ...
# 932       0
# 933       0
# 934       0
# 935       0
# 936       0
#
# [937 rows x 28 columns]

# %% [markdown]
# # 2. Data Exploring

# %%
oil_data.shape 
# output (rows no., columns no.)
# Out:
# (937, 50)

# %%
oil_data.describe()
# Out:
#               f_1           f_2          f_3          f_4         f_5  \
# count  937.000000    937.000000   937.000000   937.000000  937.000000
# mean    81.588047    332.842049   698.707086   870.992209   84.121665
# std     64.976730   1931.938570   599.965577   522.799325   45.361771
# min      1.000000     10.000000     1.920000     1.000000    0.000000
# 25%     31.000000     20.000000    85.270000   444.200000   54.000000
# 50%     64.000000     65.000000   704.370000   761.280000   73.000000
# 75%    124.000000    132.000000  1223.480000  1260.370000  117.000000
# max    352.000000  32389.000000  1893.080000  2724.570000  180.000000
#
#                 f_6         f_7         f_8            f_9        f_10  ...  \
# count  9.370000e+02  937.000000  937.000000     937.000000  937.000000  ...
# mean   7.696964e+05   43.242721    9.127887    3940.712914    0.221003  ...
# std    3.831151e+06   12.718404    3.588878    8167.427625    0.090316  ...
# min    7.031200e+04   21.240000    0.830000     667.000000    0.020000  ...
# 25%    1.250000e+05   33.650000    6.750000    1371.000000    0.160000  ...
# 50%    1.863000e+05   39.970000    8.200000    2090.000000    0.200000  ...
# 75%    3.304680e+05   52.420000   10.760000    3435.000000    0.260000  ...
# max    7.131500e+07   82.640000   24.690000  160740.000000    0.740000  ...
#
#                f_41          f_42         f_43         f_44        f_45  \
# count    937.000000    937.000000   937.000000   937.000000  937.000000
# mean     933.928677    427.565582   255.435902   106.112519    5.014002
# std     1001.681331    715.391648   534.306194   135.617708    5.029151
# min        0.000000      0.000000     0.000000     0.000000    0.000000
# 25%      450.000000    180.000000    90.800000    50.120000    2.370000
# 50%      685.420000    270.000000   161.650000    73.850000    3.850000
# 75%     1053.420000    460.980000   265.510000   125.810000    6.320000
# max    11949.330000  11500.000000  9593.480000  1748.130000   76.630000
#
#              f_46          f_47        f_48        f_49      target
# count  937.000000    937.000000  937.000000  937.000000  937.000000
# mean     0.128068   7985.718004   61.694386    8.119723    0.043757
# std      0.334344   6854.504915   10.412807    2.908895    0.204662
# min      0.000000   2051.500000   35.950000    5.810000    0.000000
# 25%      0.000000   3760.570000   65.720000    6.340000    0.000000
# 50%      0.000000   5509.430000   65.930000    7.220000    0.000000
# 75%      0.000000   9521.930000   66.130000    7.840000    0.000000
# max      1.000000  55128.460000   66.450000   15.440000    1.000000
#
# [8 rows x 50 columns]

# %%
oil_data.columns
# Out:
# Index(['f_1', 'f_2', 'f_3', 'f_4', 'f_5', 'f_6', 'f_7', 'f_8', 'f_9', 'f_10',
#        'f_11', 'f_12', 'f_13', 'f_14', 'f_15', 'f_16', 'f_17', 'f_18', 'f_19',
#        'f_20', 'f_21', 'f_22', 'f_23', 'f_24', 'f_25', 'f_26', 'f_27', 'f_28',
#        'f_29', 'f_30', 'f_31', 'f_32', 'f_33', 'f_34', 'f_35', 'f_36', 'f_37',
#        'f_38', 'f_39', 'f_40', 'f_41', 'f_42', 'f_43', 'f_44', 'f_45', 'f_46',
#        'f_47', 'f_48', 'f_49', 'target'],
#       dtype='object')

# %%
oil_data.target.value_counts()
# Out:
# 0    896
# 1     41
# Name: target, dtype: int64

# %% [markdown]
# 1. The graph above shows that the majority goes for the value of **Zero** which is **Non-Spill (negative case)**
# 2. And the minority goes for the value of **One** which is **Oil Spill (positive case)**

# %% [markdown]
# # 3.  Data Visualization

# %% [markdown]
# ## 3.1 target count plot

# %%
# Set the width and height of the figure
plt.figure(figsize=(10, 6))

# Add title
plt.title("Oil Spilling - Classes")

# Bar chart showing average arrival delay for Spirit Airlines flights by month
sns.countplot(x='target', hue='target', data=oil_data)
# Out:
# <AxesSubplot:title={'center':'Oil Spilling - Classes'}, xlabel='target', ylabel='count'>

# %% [markdown]
# ## 3.2 find correlation

# %%
# Correlation between different variables
#
corr = oil_data.corr()
#
# Set up the matplotlib plot configuration
#
f, ax = plt.subplots(figsize=(25, 15))

# Draw the heatmap

sns.heatmap(corr)
# Out:
# <AxesSubplot:>

# %% [markdown]
# the correlation graph above shows that `f_47`, `f_41`, and `f_11` have a positive correlation with the `target`

# %% [markdown]
# the graph also shows that `f_23` has the same value which I have to drop it since it'll not affect the data

# %%
oil_data.columns
# Out:
# Index(['f_1', 'f_2', 'f_3', 'f_4', 'f_5', 'f_6', 'f_7', 'f_8', 'f_9', 'f_10',
#        'f_11', 'f_12', 'f_13', 'f_14', 'f_15', 'f_16', 'f_17', 'f_18', 'f_19',
#        'f_20', 'f_21', 'f_22', 'f_23', 'f_24', 'f_25', 'f_26', 'f_27', 'f_28',
#        'f_29', 'f_30', 'f_31', 'f_32', 'f_33', 'f_34', 'f_35', 'f_36', 'f_37',
#        'f_38', 'f_39', 'f_40', 'f_41', 'f_42', 'f_43', 'f_44', 'f_45', 'f_46',
#        'f_47', 'f_48', 'f_49', 'target'],
#       dtype='object')

# %%
def visualize_scatterplot(df, cols,target):
    plt.figure(figsize=(20,20))
    plt.subplots_adjust(hspace=0.2)
    plt.suptitle("`F` columns distribution",
                 fontsize=18, y=1)
    for i, col in enumerate(cols):
        plt.subplot(7, 7, i+1)
        # plt.title(f'{col}')
        x = col
        sns.scatterplot(x=x, y=target, data=df)
    plt.tight_layout()
    plt.show()

# %%
cols = oil_data.columns[:47]
visualize_scatterplot(oil_data, cols, oil_data['target'])

# %%
def visualize_boxplot(df, cols):
    plt.figure(figsize=(20, 20))
    plt.subplots_adjust(hspace=0.2)
    plt.suptitle("`F` columns distribution",
                 fontsize=18, y=1)
    for i, col in enumerate(cols):
        plt.subplot(7, 7, i+1)
        # plt.title(f'{col}')
        x = col
        sns.boxplot(x=x, data=df)
    plt.tight_layout()
    plt.show()

# %%
cols = oil_data.columns[:47]
visualize_boxplot(oil_data, cols)

# %% [markdown]
# - The graph above shows that the F columns

# %% [markdown]
# # 3. Data preprocessing

# %% [markdown]
# ## 3.1 Assess missing values

# %%
oil_data.isnull().sum()
# Out:
# f_1       0
# f_2       0
# f_3       0
# f_4       0
# f_5       0
# f_6       0
# f_7       0
# f_8       0
# f_9       0
# f_10      0
# f_11      0
# f_12      0
# f_13      0
# f_14      0
# f_15      0
# f_16      0
# f_17      0
# f_18      0
# f_19      0
# f_20      0
# f_21      0
# f_22      0
# f_23      0
# f_24      0
# f_25      0
# f_26      0
# f_27      0
# f_28      0
# f_29      0
# f_30      0
# f_31      0
# f_32      0
# f_33      0
# f_34      0
# f_35      0
# f_36      0
# f_37      0
# f_38      0
# f_39      0
# f_40      0
# f_41      0
# f_42      0
# f_43      0
# f_44      0
# f_45      0
# f_46      0
# f_47      0
# f_48      0
# f_49      0
# target    0
# dtype: int64

# %% [markdown]
# - As the above output shows there are no missing values

# %%
oil_data.columns
# Out:
# Index(['f_1', 'f_2', 'f_3', 'f_4', 'f_5', 'f_6', 'f_7', 'f_8', 'f_9', 'f_10',
#        'f_11', 'f_12', 'f_13', 'f_14', 'f_15', 'f_16', 'f_17', 'f_18', 'f_19',
#        'f_20', 'f_21', 'f_22', 'f_23', 'f_24', 'f_25', 'f_26', 'f_27', 'f_28',
#        'f_29', 'f_30', 'f_31', 'f_32', 'f_33', 'f_34', 'f_35', 'f_36', 'f_37',
#        'f_38', 'f_39', 'f_40', 'f_41', 'f_42', 'f_43', 'f_44', 'f_45', 'f_46',
#        'f_47', 'f_48', 'f_49', 'target'],
#       dtype='object')

# %% [markdown]
# * (0) Non-Spill: negative case, or majority class.
# * (1) Oil Spill: positive case, or minority class.

# %% [markdown]
# ## 3.3 Drop the column `f_23`

# %%
oil_data['f_23'].value_counts()
# Out:
# 0    937
# Name: f_23, dtype: int64

# %%
oil_data.drop('f_23', axis=1, inplace=True)

# %%
oil_data.columns
# Out:
# Index(['f_1', 'f_2', 'f_3', 'f_4', 'f_5', 'f_6', 'f_7', 'f_8', 'f_9', 'f_10',
#        'f_11', 'f_12', 'f_13', 'f_14', 'f_15', 'f_16', 'f_17', 'f_18', 'f_19',
#        'f_20', 'f_21', 'f_22', 'f_24', 'f_25', 'f_26', 'f_27', 'f_28', 'f_29',
#        'f_30', 'f_31', 'f_32', 'f_33', 'f_34', 'f_35', 'f_36', 'f_37', 'f_38',
#        'f_39', 'f_40', 'f_41', 'f_42', 'f_43', 'f_44', 'f_45', 'f_46', 'f_47',
#        'f_48', 'f_49', 'target'],
#       dtype='object')

# %% [markdown]
# `f_23` is already dropped

# %% [markdown]
# ## 3.2 Splitting Data

# %%
y = oil_data.iloc[:,-1]
y
# Out:
# 0      1
# 1      0
# 2      1
# 3      1
# 4      0
#       ..
# 932    0
# 933    0
# 934    0
# 935    0
# 936    0
# Name: target, Length: 937, dtype: int64

# %%
X = oil_data.iloc[:,:-1]
X
# Out:
#      f_1    f_2      f_3     f_4  f_5       f_6    f_7    f_8      f_9  f_10  \
# 0      1   2558  1506.09  456.63   90   6395000  40.88   7.89  29780.0  0.19
# 1      2  22325    79.11  841.03  180  55812500  51.11   1.21  61900.0  0.02
# 2      3    115  1449.85  608.43   88    287500  40.42   7.34   3340.0  0.18
# 3      4   1201  1562.53  295.65   66   3002500  42.40   7.97  18030.0  0.19
# 4      5    312   950.27  440.86   37    780000  41.43   7.03   3350.0  0.17
# ..   ...    ...      ...     ...  ...       ...    ...    ...      ...   ...
# 932  200     12    92.42  364.42  135     97200  59.42  10.34    884.0  0.17
# 933  201     11    98.82  248.64  159     89100  59.64  10.18    831.0  0.17
# 934  202     14    25.14  428.86   24    113400  60.14  17.94    847.0  0.30
# 935  203     10    96.00  451.30   68     81000  59.90  15.01    831.0  0.25
# 936  204     11     7.73  235.73  135     89100  61.82  12.24    831.0  0.20
#
#      ...  f_40     f_41      f_42     f_43     f_44   f_45  f_46      f_47  \
# 0    ...    69  2850.00   1000.00   763.16   135.46   3.73     0  33243.19
# 1    ...    69  5750.00  11500.00  9593.48  1648.80   0.60     0  51572.04
# 2    ...    69  1400.00    250.00   150.00    45.13   9.33     1  31692.84
# 3    ...    69  6041.52    761.58   453.21   144.97  13.33     1  37696.21
# 4    ...    69  1320.04    710.63   512.54   109.16   2.58     0  29038.17
# ..   ...   ...      ...       ...      ...      ...    ...   ...       ...
# 932  ...    50   381.84    254.56    84.85   146.97   4.50     0   2593.50
# 933  ...    50   284.60    180.00   150.00    51.96   1.90     0   4361.25
# 934  ...    50   402.49    180.00   180.00     0.00   2.24     0   2153.05
# 935  ...    50   402.49    180.00    90.00    73.48   4.47     0   2421.43
# 936  ...    50   254.56    254.56   127.28   180.00   2.00     0   3782.68
#
#       f_48  f_49
# 0    65.74  7.95
# 1    65.73  6.26
# 2    65.81  7.84
# 3    65.67  8.07
# 4    65.66  7.35
# ..     ...   ...
# 932  65.85  6.39
# 933  65.70  6.53
# 934  65.91  6.12
# 935  65.97  6.32
# 936  65.65  6.26
#
# [937 rows x 48 columns]

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaled_x = scaler.fit_transform(X)

# %%
scaled_x
# Out:
# array([[-1.24092248,  1.15238979,  1.34643407, ...,  3.68676672,
#          0.38873035, -0.05837721],
#        [-1.22552414, 11.38954577, -1.03327258, ...,  6.36218073,
#          0.38776948, -0.6396642 ],
#        [-1.21012579, -0.11281849,  1.2526453 , ...,  3.46046621,
#          0.39545643, -0.09621246],
#        ...,
#        [ 1.85414469, -0.1651255 , -1.12327578, ..., -0.8513792 ,
#          0.40506512, -0.68781815],
#        [ 1.86954303, -0.16719707, -1.00510593, ..., -0.81220448,
#          0.41083033, -0.61902679],
#        [ 1.88494138, -0.16667918, -1.15230961, ..., -0.6135064 ,
#          0.38008253, -0.6396642 ]])

# %% [markdown]
# As the scaled dataframe above shown that the features `F` are scaled by `StandardScaler` which means scaling each feature to mean 0 and standard deviation 1.

# %%
from sklearn.model_selection import train_test_split
train_X, test_X, train_y, test_y = train_test_split(
    scaled_x, y, random_state=0, test_size=0.25)

# %%
print(f'train_X shape = {train_X.shape}')
print(f'test_X shape = {test_X.shape}')
print(f'train_y shape = {train_y.shape}')
print(f'test_y shape = {test_y.shape}')
# Out:
# train_X shape = (702, 48)
# test_X shape = (235, 48)
# train_y shape = (702,)
# test_y shape = (235,)

# %% [markdown]
# # 4. Fitting the model to the data

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error

forest_model = RandomForestRegressor(random_state=1)
forest_model.fit(train_X, train_y)
oil_spill_preds = forest_model.predict(test_X)
print('MAE',mean_absolute_error(test_y, oil_spill_preds))
# Out:
# MAE 0.05965957446808511

# %% [markdown]
# ## 4.1 Solving the problem of Majority class
# ###  4.1.1 Oversampling the Minority class

# %%
oil_data.shape
# Out:
# (937, 49)

# %%
import sys
# !{sys.executable} -m pip install imbalanced-learn
# Out:
# Collecting imbalanced-learn
#   Downloading imbalanced_learn-0.10.0-py3-none-any.whl (225 kB)
# Requirement already satisfied: scikit-learn>=1.0.2 in c:\users\mizia\anaconda3\lib\site-packages (from imbalanced-learn) (1.0.2)
# Collecting joblib>=1.1.1
#   Downloading joblib-1.2.0-py3-none-any.whl (297 kB)
# Requirement already satisfied: scipy>=1.3.2 in c:\users\mizia\anaconda3\lib\site-packages (from imbalanced-learn) (1.7.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\mizia\anaconda3\lib\site-packages (from imbalanced-learn) (2.2.0)
# Requirement already satisfied: numpy>=1.17.3 in c:\users\mizia\anaconda3\lib\site-packages (from imbalanced-learn) (1.21.5)
# Installing collected packages: joblib, imbalanced-learn
#   Attempting uninstall: joblib
#     Found existing installation: joblib 1.1.0
#     Uninstalling joblib-1.1.0:
#       Successfully uninstalled joblib-1.1.0
# Successfully installed imbalanced-learn-0.10.0 joblib-1.2.0

# %%
# pip install imbalanced-learn
from imblearn.over_sampling import RandomOverSampler
from collections import Counter
print('Before oversampling the minority class, (y) shape =', Counter(y))
# define oversampling strategy
oversample = RandomOverSampler(
    sampling_strategy='not majority')  # or sampling_strategy=0.5
# fit and apply the transform
X_over, y_over = oversample.fit_resample(X, y)
# summarize class distribution
print('After oversampling the minority class, (y) shape =', Counter(y_over))
# Out:
# Before oversampling the minority class, (y) shape = Counter({0: 896, 1: 41})
# After oversampling the minority class, (y) shape = Counter({1: 896, 0: 896})

# %% [markdown]
# ### 4.1.2 Spliting the new oversampled `target` column to fit the model

# %%
train_X, test_X, train_y, test_y = train_test_split(
    X_over, y_over, random_state=0, test_size=0.25)
forest_model.fit(train_X, train_y)
oil_spill_preds = forest_model.predict(test_X)
print('MAE',mean_absolute_error(test_y, oil_spill_preds))
# Out:
# MAE 0.02772321428571429

# %% [markdown]
# ### 4.1.3 Try using another strategy for oversampling like haveing the half of majority class

# %%
print('Before oversampling the minority class, (y) shape =', Counter(y))
# define oversampling strategy
oversample = RandomOverSampler(
    sampling_strategy=0.5)
# fit and apply the transform
X_over, y_over = oversample.fit_resample(X, y)
# summarize class distribution
print('After oversampling the minority class, (y) shape =', Counter(y_over))
# Out:
# Before oversampling the minority class, (y) shape = Counter({0: 896, 1: 41})
# After oversampling the minority class, (y) shape = Counter({0: 896, 1: 448})

# %% [markdown]
# ### 4.1.4 Spliting the new oversampled `target` column to fit the model

# %%
train_X, test_X, train_y, test_y = train_test_split(
    X_over, y_over, random_state=0, test_size=0.25)
forest_model.fit(train_X, train_y)
oil_spill_preds = forest_model.predict(test_X)
print('MAE',mean_absolute_error(test_y, oil_spill_preds))
# Out:
# MAE 0.03172619047619048

# %% [markdown]
# - As it is shown above that the final result of MAE which equals 0.029 is the best values,
# so I will take in my consideration the oversampling using the ratio of 0.5 the majority class
